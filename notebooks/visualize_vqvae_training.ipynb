# %%
import json
import matplotlib.pyplot as plt

maze_type = 'spiral'
exp_name = 'curriculum'
mode = 'identity'
use_curriculum = True

with open('../logs/vqvae/{}/{}/{}/loss.json'.format(maze_type, exp_name, mode), encoding='utf-8') as f:
    data = json.load(f)

plt.plot(data)
plt.grid()
plt.title('loss')
plt.show()
